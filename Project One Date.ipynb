# %%
import pandas as pd
import numpy as np
info = pd.read_csv("korean_drama.csv")
review = pd.read_csv("reviews.csv")

# %%
info
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
# 1751  c19353bdbc7a43ae98b27db202e7c908              Crow Building  2015
#
#                                director                         screenwriter  \
# ...

# %%
review
# Out:
#                                 user_id                            title  \
# 0      c8ffdab3f2a338eeb54b265598dbbb55                    Sing My Crush
# 1      c8ffdab3f2a338eeb54b265598dbbb55               Happy Merry Ending
# 2      c8ffdab3f2a338eeb54b265598dbbb55        Duty After School: Part 2
# 3      c8ffdab3f2a338eeb54b265598dbbb55                   Our Dating Sim
# 4      c8ffdab3f2a338eeb54b265598dbbb55  The Director Who Buys Me Dinner
# ...                                 ...                              ...
# 10620  33bb7ae6e00a345c927f1b8e39594908                   Heart to Heart
# 10621  e5d4bbe315b03eb4878aa84d2f4fcff0                 Kill Me, Heal Me
# 10622  43aaace8631f36eda17a1880c7329a82                 Kill Me, Heal Me
# 10623  172b38a4599f3a649fe192fb967ce084                 Kill Me, Heal Me
# 10624  2ab12227bf5b3a39bcc82161ddfa5ea5                 Kill Me, Heal Me
#
#        story_score  acting_cast_score  music_score  rewatch_value_score  \
# ...

# %%
info.drop(info.tail(1).index,inplace=True) # drop last n rows
info
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1746  98058140526d426eb878360903776f3d             Heart to Heart  2015
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
#
#                                director                         screenwriter  \
# ...

# %%
print(info.loc[[482]])
# Out:
#                             kdrama_id                     drama_name  year  \
# 482  cb1fcbaf4405470487e84f4d11d90055  Girlfriend in The Men's Group  2021
#
#     director screenwriter      country   type  tot_eps  duration  \
# 482      NaN          NaN  South Korea  Drama        7     600.0
#
#                   start_dt                 end_dt aired_on org_net  \
# 482  May, 2021 - Jul, 2021  May, 2021 - Jul, 2021      NaN     NaN
#
#         content_rt                                           synopsis   rank  \
# 482  Not Yet Rated  Wisdom and the Nam Sachin's Su Ju, Ho Tae, Jin...  55505
#
#        pop
# 482  15555

# %%
info = info.drop(482)
info
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1746  98058140526d426eb878360903776f3d             Heart to Heart  2015
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
#
#                                director                         screenwriter  \
# ...

# %%
print(info.loc[[1331]])
# Out:
#                              kdrama_id   drama_name  year director  \
# 1331  e5ead88b53794fcdbfe3b3db397e4f49  No Bad Days  2017      NaN
#
#      screenwriter      country   type  tot_eps  duration          start_dt  \
# 1331          NaN  South Korea  Drama       10     240.0  Aug, 2017 - 2017
#
#                 end_dt aired_on org_net     content_rt  \
# 1331  Aug, 2017 - 2017      NaN     NaN  Not Yet Rated
#
#                                                synopsis   rank    pop
# 1331  An ordinary female protagonist in her twenties...  43201  99999

# %%
info = info.drop(1331)
info
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1746  98058140526d426eb878360903776f3d             Heart to Heart  2015
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
#
#                                director                         screenwriter  \
# ...

# %%
print(info.loc[[1511]])
# Out:
#                              kdrama_id     drama_name  year director  \
# 1511  763ad7afe7834229840ba31a84f7847f  Romantic Boss  2016      NaN
#
#      screenwriter      country   type  tot_eps  duration  \
# 1511          NaN  South Korea  Drama       12     900.0
#
#                    start_dt                 end_dt aired_on        org_net  \
# 1511  Aug, 2016 - Oct, 2016  Aug, 2016 - Oct, 2016      NaN  Naver TV Cast
#
#          content_rt                                           synopsis   rank  \
# 1511  Not Yet Rated  The story of a diverse group of young adult pr...  55258
#
#         pop
# 1511  14549

# %%
info = info.drop(1511)
info
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1746  98058140526d426eb878360903776f3d             Heart to Heart  2015
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
#
#                                director                         screenwriter  \
# ...

# %%
import datetime
info["start_dt"] = pd.to_datetime(info["start_dt"])
info
# Out:
# /var/folders/mf/hq3v06dx7sdgx_rh48zsrm5m0000gn/T/ipykernel_4899/2280998712.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   info["start_dt"] = pd.to_datetime(info["start_dt"])
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1746  98058140526d426eb878360903776f3d             Heart to Heart  2015
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# ...

# %%
info["start_dt"] = info["start_dt"].dt.strftime('%m-%d-%Y')

# %%
info
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1746  98058140526d426eb878360903776f3d             Heart to Heart  2015
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
#
#                                director                         screenwriter  \
# ...

# %%
info["end_dt"] = pd.to_datetime(info["end_dt"])
info
# Out:
# /var/folders/mf/hq3v06dx7sdgx_rh48zsrm5m0000gn/T/ipykernel_4899/1501859279.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   info["end_dt"] = pd.to_datetime(info["end_dt"])
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1746  98058140526d426eb878360903776f3d             Heart to Heart  2015
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# ...

# %%
info["end_dt"] = info["end_dt"].dt.strftime('%m-%d-%Y')
info
# Out:
#                              kdrama_id                 drama_name  year  \
# 0     661d4193916c4e71a2c70473ab11e9e8              Sing My Crush  2023
# 1     5ffcbeaa17114714af1959129984274c              D.P. Season 2  2023
# 2     65075cb9c1a54be4a441cee6f16c9fdf  Shadow Detective Season 2  2023
# 3     df0f0ac4b3ff4b15afa26f5a7a53a328               To Be Honest  2023
# 4     04c1fe41948e464fb440001831d74d41                  Celebrity  2023
# ...                                ...                        ...   ...
# 1746  98058140526d426eb878360903776f3d             Heart to Heart  2015
# 1747  e8c09f0f7d0d4b75a4642eb06d76d811           Kill Me, Heal Me  2015
# 1748  1e7f7f2fa45d4240b8bb585ca13040f0        Enchanting Neighbor  2015
# 1749  142a09741fdd4daa878d6ae007201e43              Iron Lady Cha  2015
# 1750  9170c31a02014b56bb4cec2105086f00       The Family Is Coming  2015
#
#                                director                         screenwriter  \
# ...

# %%
info.to_csv('out.csv')
